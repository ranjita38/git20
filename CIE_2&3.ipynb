# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjita38/git20/blob/main/CIE_2%263.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/Titanic-Dataset (3).csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       NaN       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     883 non-null    float64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  883.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.378256    2.308642   29.699118    0.523008
# std     257.353842    0.485227    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False      True   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
print(df['Age'].isna().sum())
# Out:
# 177

# %%
print(df['Survived'].isna().sum())
# Out:
# 8

# %% [markdown]
# cie-3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/auto-mpg (1).csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
x=df[["displacement"]]
x
y=df[["weight"]]
y
# Out:
#      weight
# 0      3504
# 1      3693
# 2      3436
# 3      3433
# 4      3449
# ..      ...
# 393    2790
# 394    2130
# 395    2295
# 396    2625
# 397    2720
#
# [398 rows x 1 columns]

# %%
sns.scatterplot(x="displacement",y="weight",data=df)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train
x_test
y_train
y_test
# Out:
#      weight
# 341    2725
# 378    2125
# 312    2019
# 315    3003
# 374    3035
# ..      ...
# 308    2556
# 296    2670
# 64     4135
# 365    3060
# 273    2405
#
# [80 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)
print(x_pred)
print(y_pred)
# Out:
# [[4167.82326802]
#  [4160.21307403]
#  [4236.31501389]
#  [3810.14415071]
#  [3208.93882588]
#  [3810.14415071]
#  [3460.07522739]
#  [2889.3106785 ]
#  [2189.17283185]
#  [3011.07378226]
#  [2356.59709953]
#  [2425.0888454 ]
#  [4160.21307403]
#  [2676.22524691]
#  [3817.7543447 ]
#  [2417.47865141]
#  [2797.98835067]
#  [3399.19367551]
#  [4160.21307403]
#  [3262.21018377]
#  [4160.21307403]
#  [2143.51166794]
#  [2318.5461296 ]
#  [2775.15776872]
#  [2295.71554765]
#  [3460.07522739]
#  [2242.44418975]
#  [2242.44418975]
#  [2379.42768148]
#  [4951.6732485 ]
#  [4540.7227733 ]
#  [2234.83399577]
#  [2775.15776872]
#  [2348.98690554]
#  [2516.41117322]
#  [2242.44418975]
#  [3490.51600333]
#  [2562.07233713]
#  [3399.19367551]
#  [2238.63909276]
#  [3254.59998979]
#  [3399.19367551]
#  [3399.19367551]
#  [3832.97473267]
#  [2425.0888454 ]
#  [3916.6868665 ]
#  [3810.14415071]
#  [2425.0888454 ]
#  [2044.57914613]
#  [2181.56263787]
#  [2166.3422499 ]
#  [2417.47865141]
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_train,x_pred)
mse=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(mean_squared_error)
print(mean_absolute_error)
print('R2 Score:',r2)
# Out:
# <function mean_squared_error at 0x7b01b2de36a0>
# <function mean_absolute_error at 0x7b01b2de32e0>
# R2 Score: 0.8777599767714437

# %%
import numpy as np
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print('Root Mean Squared Error:',rmse)
# Out:
# Root Mean Squared Error: 270.0075328505363

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,lr.predict(x_train),color='blue')
plt.title('linear regression model')
plt.xlabel('Displacement')
plt.ylabel('Weight')
plt.show()
